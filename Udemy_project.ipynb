# %%
# Import libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns

# makes sure charts appear in the notebook rather than a popup window
# %matplotlib inline

# %%
#Import csv file

ud = pd.read_csv("3.1-data-sheet-udemy-courses-business-courses.csv")
ud
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 1187  1231958.0        60 Minutes to Fundamental Accounting Skills
# 1188  1057040.0                           Teeter-Totter Accounting
# 1189  1258666.0                Financial Statement Auditing Cycles
# 1190  1232282.0          The Cash Flow Statement - An Introduction
# 1191        NaN                                                NaN
#
#                                                     url  price  \
# 0     https://www.udemy.com/bitcoin-or-how-i-learned...    0.0
# 1     https://www.udemy.com/accounting-in-60-minutes...    0.0
# 2     https://www.udemy.com/the-beginners-guide-to-t...    0.0
# 3     https://www.udemy.com/financial-modeling-asimp...    0.0
# 4     https://www.udemy.com/the-complete-financial-a...  195.0
# ...                                                 ...    ...
# 1187  https://www.udemy.com/60-minute-fundamental-ac...   75.0
# 1188    https://www.udemy.com/teeter-totter-accounting/   90.0
# 1189  https://www.udemy.com/financial-statement-audi...   50.0
# 1190  https://www.udemy.com/cash-flow-statement-intr...   50.0
# 1191                                                NaN    NaN
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 0             65576.0        936.0          24.0          All Levels
# 1             56659.0       4397.0          16.0      Beginner Level
# 2             50855.0       2698.0          15.0          All Levels
# 3             29167.0       1463.0           8.0          All Levels
# 4             24481.0       2347.0         174.0          All Levels
# ...               ...          ...           ...                 ...
# 1187              0.0          0.0           9.0          All Levels
# 1188              0.0          0.0          12.0  Intermediate Level
# 1189              0.0          0.0           9.0          All Levels
# 1190              0.0          0.0          10.0          All Levels
# 1191              NaN          NaN           NaN                 NaN
#
#         Rating  content_duration   published_timestamp           subject
# 0     0.560000               8.0  2013-04-20T02:25:22Z  Business Finance
# 1     0.950000               1.5  2013-04-07T21:39:25Z  Business Finance
# 2     0.910000               1.5  2013-12-25T19:53:34Z  Business Finance
# 3     0.180000               1.5  2014-05-27T16:22:16Z  Business Finance
# 4     0.370000              10.0  2016-01-21T01:38:48Z  Business Finance
# ...        ...               ...                   ...               ...
# 1187  0.950000               2.5  2017-06-28T21:55:29Z  Business Finance
# 1188  0.360000               1.0  2017-02-08T22:15:56Z  Business Finance
# 1189  0.150000               2.0  2017-06-29T23:20:10Z  Business Finance
# 1190  0.180000               1.5  2017-06-28T16:05:51Z  Business Finance
# 1191  0.690353               NaN                   NaN               NaN
#
# [1192 rows x 12 columns]

# %%
#Check the data types

ud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1192 entries, 0 to 1191
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            1191 non-null   float64
#  1   course_title         1191 non-null   object
#  2   url                  1191 non-null   object
#  3   price                1191 non-null   float64
#  4   num_subscribers      1191 non-null   float64
#  5   num_reviews          1191 non-null   float64
#  6   num_lectures         1191 non-null   float64
#  7   level                1191 non-null   object
#  8   Rating               1192 non-null   float64
#  9   content_duration     1191 non-null   float64
#  10  published_timestamp  1191 non-null   object
#  11  subject              1191 non-null   object
# dtypes: float64(7), object(5)
# memory usage: 111.9+ KB

# %%
#Check the number of null values

ud.isna().sum()
# Out:
# course_id              1
# course_title           1
# url                    1
# price                  1
# num_subscribers        1
# num_reviews            1
# num_lectures           1
# level                  1
# Rating                 0
# content_duration       1
# published_timestamp    1
# subject                1
# dtype: int64

# %%
#Check the maximum rate in order to understand what is the unit of the Rating column

ud["Rating"].max()

#We will multiply the rating by 10 in order to have a rate / 10 instead of a float
# Out:
# 1.0

# %%
#Check if there are duplicates

ud["course_id"].nunique()

#There are 1191 unique values, and we know that there is one null value in the course_id column, so all the other course_id are uniques.
# Out:
# 1191

# %%
#Remove the null values

ud = ud.dropna(subset=['course_id'])

#ud["course_id"] = ud["course_id"].drop(1191)
#ud["course_id"]

# %%
ud
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 1186   885413.0                           Foundations of Investing
# 1187  1231958.0        60 Minutes to Fundamental Accounting Skills
# 1188  1057040.0                           Teeter-Totter Accounting
# 1189  1258666.0                Financial Statement Auditing Cycles
# 1190  1232282.0          The Cash Flow Statement - An Introduction
#
#                                                     url  price  \
# 0     https://www.udemy.com/bitcoin-or-how-i-learned...    0.0
# 1     https://www.udemy.com/accounting-in-60-minutes...    0.0
# 2     https://www.udemy.com/the-beginners-guide-to-t...    0.0
# 3     https://www.udemy.com/financial-modeling-asimp...    0.0
# 4     https://www.udemy.com/the-complete-financial-a...  195.0
# ...                                                 ...    ...
# 1186    https://www.udemy.com/foundations-of-investing/   40.0
# 1187  https://www.udemy.com/60-minute-fundamental-ac...   75.0
# 1188    https://www.udemy.com/teeter-totter-accounting/   90.0
# 1189  https://www.udemy.com/financial-statement-audi...   50.0
# 1190  https://www.udemy.com/cash-flow-statement-intr...   50.0
#
#       num_subscribers  num_reviews  num_lectures               level  Rating  \
# 0             65576.0        936.0          24.0          All Levels    0.56
# 1             56659.0       4397.0          16.0      Beginner Level    0.95
# 2             50855.0       2698.0          15.0          All Levels    0.91
# 3             29167.0       1463.0           8.0          All Levels    0.18
# 4             24481.0       2347.0         174.0          All Levels    0.37
# ...               ...          ...           ...                 ...     ...
# 1186              0.0          0.0          18.0      Beginner Level    0.95
# 1187              0.0          0.0           9.0          All Levels    0.95
# 1188              0.0          0.0          12.0  Intermediate Level    0.36
# 1189              0.0          0.0           9.0          All Levels    0.15
# 1190              0.0          0.0          10.0          All Levels    0.18
#
#       content_duration   published_timestamp           subject
# 0                  8.0  2013-04-20T02:25:22Z  Business Finance
# 1                  1.5  2013-04-07T21:39:25Z  Business Finance
# 2                  1.5  2013-12-25T19:53:34Z  Business Finance
# 3                  1.5  2014-05-27T16:22:16Z  Business Finance
# 4                 10.0  2016-01-21T01:38:48Z  Business Finance
# ...                ...                   ...               ...
# 1186               2.0  2016-07-27T21:07:46Z  Business Finance
# 1187               2.5  2017-06-28T21:55:29Z  Business Finance
# 1188               1.0  2017-02-08T22:15:56Z  Business Finance
# 1189               2.0  2017-06-29T23:20:10Z  Business Finance
# 1190               1.5  2017-06-28T16:05:51Z  Business Finance
#
# [1191 rows x 12 columns]

# %%
#Convert data types

ud["course_id"] = ud["course_id"].astype(int)
ud["num_subscribers"] = ud["num_subscribers"].astype(int)
ud["num_reviews"] = ud["num_reviews"].astype(int)
ud["num_lectures"] = ud["num_lectures"].astype(int)
# Out:
# /var/folders/xp/jp6pr1sn3p50vy46h4q0ntqr0000gn/T/ipykernel_82404/2715242729.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ud["course_id"] = ud["course_id"].astype(int)
# /var/folders/xp/jp6pr1sn3p50vy46h4q0ntqr0000gn/T/ipykernel_82404/2715242729.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ud["num_subscribers"] = ud["num_subscribers"].astype(int)
# /var/folders/xp/jp6pr1sn3p50vy46h4q0ntqr0000gn/T/ipykernel_82404/2715242729.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ud["num_reviews"] = ud["num_reviews"].astype(int)
# /var/folders/xp/jp6pr1sn3p50vy46h4q0ntqr0000gn/T/ipykernel_82404/2715242729.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ud["num_lectures"] = ud["num_lectures"].astype(int)

# %%
ud["Rating"] = ud["Rating"] * 10
# Out:
# /var/folders/xp/jp6pr1sn3p50vy46h4q0ntqr0000gn/T/ipykernel_82404/2107831108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ud["Rating"] = ud["Rating"] * 10

# %%
ud.loc[(ud["course_id"] == 52118), "course_title"].str.split(',')
# Out:
#      course_id                                       course_title  \
# 147      52118  Multiply your returns using 'Value Investing",...
#
#                                                    url  price  \
# 147  https://www.udemy.com/weekly-forex-analysis-by...    0.0
#
#      num_subscribers  num_reviews  num_lectures           level  Rating  \
# 147             3035           12            14  Beginner Level     9.6
#
#      content_duration   published_timestamp           subject
# 147               1.5  2016-06-20T21:02:36Z  Business Finance

# %%
ud
# Out:
#       course_id                                       course_title  \
# 0         49798  Bitcoin or How I Learned to Stop Worrying and ...
# 1         48841    Accounting in 60 Minutes - A Brief Introduction
# 2        133536               Stock Market Investing for Beginners
# 3        151668                 Introduction to Financial Modeling
# 4        648826         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 1186     885413                           Foundations of Investing
# 1187    1231958        60 Minutes to Fundamental Accounting Skills
# 1188    1057040                           Teeter-Totter Accounting
# 1189    1258666                Financial Statement Auditing Cycles
# 1190    1232282          The Cash Flow Statement - An Introduction
#
#                                                     url  price  \
# 0     https://www.udemy.com/bitcoin-or-how-i-learned...    0.0
# 1     https://www.udemy.com/accounting-in-60-minutes...    0.0
# 2     https://www.udemy.com/the-beginners-guide-to-t...    0.0
# 3     https://www.udemy.com/financial-modeling-asimp...    0.0
# 4     https://www.udemy.com/the-complete-financial-a...  195.0
# ...                                                 ...    ...
# 1186    https://www.udemy.com/foundations-of-investing/   40.0
# 1187  https://www.udemy.com/60-minute-fundamental-ac...   75.0
# 1188    https://www.udemy.com/teeter-totter-accounting/   90.0
# 1189  https://www.udemy.com/financial-statement-audi...   50.0
# 1190  https://www.udemy.com/cash-flow-statement-intr...   50.0
#
#       num_subscribers  num_reviews  num_lectures               level  Rating  \
# 0               65576          936            24          All Levels     5.6
# 1               56659         4397            16      Beginner Level     9.5
# 2               50855         2698            15          All Levels     9.1
# 3               29167         1463             8          All Levels     1.8
# 4               24481         2347           174          All Levels     3.7
# ...               ...          ...           ...                 ...     ...
# 1186                0            0            18      Beginner Level     9.5
# 1187                0            0             9          All Levels     9.5
# 1188                0            0            12  Intermediate Level     3.6
# 1189                0            0             9          All Levels     1.5
# 1190                0            0            10          All Levels     1.8
#
#       content_duration   published_timestamp           subject
# 0                  8.0  2013-04-20T02:25:22Z  Business Finance
# 1                  1.5  2013-04-07T21:39:25Z  Business Finance
# 2                  1.5  2013-12-25T19:53:34Z  Business Finance
# 3                  1.5  2014-05-27T16:22:16Z  Business Finance
# 4                 10.0  2016-01-21T01:38:48Z  Business Finance
# ...                ...                   ...               ...
# 1186               2.0  2016-07-27T21:07:46Z  Business Finance
# 1187               2.5  2017-06-28T21:55:29Z  Business Finance
# 1188               1.0  2017-02-08T22:15:56Z  Business Finance
# 1189               2.0  2017-06-29T23:20:10Z  Business Finance
# 1190               1.5  2017-06-28T16:05:51Z  Business Finance
#
# [1191 rows x 12 columns]
